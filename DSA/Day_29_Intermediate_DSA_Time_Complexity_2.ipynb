# %% [markdown]
# <a href="https://colab.research.google.com/github/Rama27SepIBM/21DaysOfLeetcode/blob/main/Day_29_Intermediate_DSA_Time_Complexity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Time Complexity Easy 01
#
# What is the Time Complexity of following snippet ?
#
# C++
# Java
# Python
#
# Q....
# count = 0
# while N > 0:
# count +=1
# N = N//3

# %%
# O(N). O(N*N). O(Nlog(N)) O(log(N)) {Base 3}

# %% [markdown]
# Q2. Time Complexity - 3B
#
# What will be the Time Complexity of the given code?
#
# C++
# Java
# Python
#
# ![WhatsApp Image 2023-04-14 at 12.33.10.jpeg](data:image/jpeg;base64,...)

# %%
# O(nlogn). O(n). O(n sqrt(n)). O(n^2). None of the above

# %% [markdown]
# Q3. Time Complexity Easy 02
#
# What is the Time Complexity of following snippet ?
#
# C++
# Java
# Python
#
# for i in range(N):
#     for j in range(i,N):
#     break

# %%
# O(N*N).  O(N*log(N)).  O(N). O(log(N)). None of the above

# %% [markdown]
# Q4. NESTED_CMPL2
#
# What is the time complexity of the following code :
#
# C++
# Java
# Python
#
#
# a = 0
# for i in range(N):
#    for j in range(N):
#    a = a+i+j

# %%
# O(N). O(N*log(N)). O(N * Sqrt(N)). O(N*N).

# %% [markdown]
# Q1. NESTED_CMPL
#
# What is the time, space complexity of following code :
#
# C++
# Java
# Python
#
#
# Q. ![WhatsApp Image 2023-04-14 at 12.40.21.jpeg](data:image/jpeg;base64,...)

# %%
# O(N * N) time, O(1) space 
# O(N) time, O(N) space
# O(N) time, O(1) space
# O(N * N) time, O(N) space
# O(N * N * N) time, O(1) space

# %% [markdown]
# Q2. Time Complexity - M4
#
# Find the Time Complexity of the following function solve :
#
# C++
# Java
# Python
# C#
# JS
#
# def solve(N):
#    for i in range(2 ** N):
#    j=1
#    while j > 0:
#       j -=1

# %%
# O(N * N). O(2^N). O(N * (2^N)). O(3^N). O(4^N)

# %% [markdown]
# Q3. Find Time Complexity
#
# What will be the time complexity of the above function where n is a positive integer?
#
# C++
# Java
# Python
# C#
# JS
#
# def function(n):
#    while n > 0:
#    n +=1
#    n -=2

# %%
# Infinite loop. O(n). O(nlogn). O(logn). None of the above

# %% [markdown]
# Q4. Time Complexity-iii
#
# What is the time complexity of the following code snippet?
#
# C++
# Java
# Python
#
# for i in range(n):
#    j = i-1
#    while (j >= 0):
#    ans += i + j
#    j +=1

# %%
# O(n). O(n^2) Code will run indefinitely. O(1) None of the above

# %% [markdown]
# Q5. Time Complexity - 8
#
#
# What is the time complexity of the following code snippet?
#
# C++
# Java
# Python
#
# sum = 0
# for i in range(N+1):
#    j = i
#    while (j <= N && j > i):
#    j +=1

# %%
# O(N^2). O(N). O(NlogN). None of these

# %% [markdown]
# Q1. NESTED_CMPL
#
# What is the time, space complexity of following code :
#
# C++
# Java
# Python
#
# a=0
# b=0
# for i in range(N):
#      for j in range(N):
#      a = a + j
# for k in range(N):
# b = b + k

# %%
# O(N * N) time, O(1) space. 
# O(N) time, O(N) space
# O(N) time, O(N) space
# O(N * N) time, O(N) space
# O(N * N * N) time, O(1) space

# %% [markdown]
# Q2. Time Complexity - M4
#
# Find the Time Complexity of the following function solve :
#
# C++
# Java
# Python
# C#
# JS
#
# def solve(N):
# for i in range(2 ** N):
#  j = i
#  while j > 0:
#  j -= 1

# %%
# O(N * N). O(2^N). O(N * (2^N)). O(3^N). O(4^N)

# %% [markdown]
# Q3. Find Time Complexity
#
# What will be the time complexity of the above function where n is a positive integer?
#
# C++
# Java
# Python
# C#
# JS
#
# def function(N):
# while (n > 0):
# n +=1
# n -=2

# %%
# Infinite loop. O(n) O(nlogn) O(logn). None of the above

# %% [markdown]
# Q4. Time Complexity-iii
#
# What is the time complexity of the following code snippet?
#
# C++
# Java
# Python
#
# for i in range(n):
#     j = i -1
#     while ( j>= 0):
#     ans += i + j
#     j +=1

# %%
# O(n).  O(n^2).  Code will run indefinitely. O(1). None of the above

# %% [markdown]
# Q5. Time Complexity - 8
#
# What is the time complexity of the following code snippet?
#
# C++
# Java
# Python
#
# sum = 0
# for i in range(N+1):
#    j = i
#    while j <= N && j > i :
#    j +=1

# %%
# O(N^2).  O(N). O(NlogN). None of these.
