# %% [markdown]
# <a href="https://colab.research.google.com/github/Rama27SepIBM/21DaysOfLeetcode/blob/main/Day_23_Beginner_Strings_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. First Occurrence
#
# You are given a character string A, having length N and an integer ASCII code B.
#
# You have to tell the leftmost occurrence of the character having ASCII code equal to B, in A or report that it does not exist.
#
# ![WhatsApp Image 2023-04-14 at 16.02.32.jpeg](data:image/jpeg;base64,...)
#
#                                                 image

# %%
class Solution:
    # @param A : string
    # @param B : integer
    # @return an integer
    def solve(self, A, B):
        B = chr(B)
        if B in A:
            return A.index(B)
        else:
            return -1

# %% [markdown]
# Q2. Length of String - II
#
# You have a string (A).
#
# You have to return length of input string.

# %%
class Solution:
    # @param A : string
    # @return an integer
    def solve(self, A):
        return len(A)

# %% [markdown]
# Q3. Replace Character
#
# You are given a character string A and two integer ASCII codes B and C.
#
# You have to find and replace all the occurrences of the character having ASCII code equal to B with character having ASCII code equal to C and return the resultant string.
# ![WhatsApp Image 2023-04-14 at 16.02.32.jpeg](data:image/jpeg;base64,...)

# %%
class Solution:
    # @param A : string
    # @param B : integer
    # @param C : integer
    # @return a strings
    def solve(self, A, B, C):
        B=chr(B)
        C=chr(C)
        return A.replace(B,C)

# %% [markdown]
# Q4. Date formatting
#
# Given the input date in DD/MM/YYYY format as a string, write a function that returns the converted date in the string formats MM/DD/YYYY and YYYY/MM/DD and return the new date formats.
#
# Input Format:
#
# First input line will have the number of test cases. There will be a single line of input for each
# testcase which will consist of date in the string format DD/MM/YYYY.
# Output Format:
#
# Resultant date formats in string formats MM/DD/YYYY and YYYY/MM/DD

# %%
def date_format(date):
    '''Input: date takes the string as input
       Output:return resultant date formats'''

    # YOUR CODE GOES HERE
    b=date.split('/')
    return(f'{b[1]}/{b[0]}/{b[2]}', f'{b[2]}/{b[1]}/{b[0]}')

# %% [markdown]
# Q5. Aliases of String
#
# If a = “Random String”, then which of the following variables has the same string value?

# %%
# c = str(a) d = a[:] e = “Rand” + “” + “om Str” + “” + “ing”

# %% [markdown]
# Q6. Upper case
# Given a list words, complete the function upper_char() to find the words from the list that have the third character in uppercase.
#
# words= ['goOd','mORNing','HOW','are','yoU','todAy']
#
# def upper_char(words):
#   output=[]
#   for i in range(len(words)):
#     _________________________:
#       output.append(words[i])
#   return output
# upper_char(words)

# %%
# if words[i][3].isupper() == False:
# if words[i][2].isupper() == False:
# if words[i][3].islower() == False:
# if words[i][2].isupper() == True:

# %% [markdown]
# Q7. Upper or Lower
#
# What will be the value of converted_word, if the following operations in the following code snippet are executed?
#
# word = "Scaler Academy"
# n = len(word)
# word1 = word.upper()
# word2 = word.lower()
#
# converted_word = ""
#
# for i in range(n):
#      if i % 2 == 0:
#           converted_word += word2[i]
#      else:
#           converted_word += word1[i]

# %%
# Scaler Academy
# ScAlEr aCaDeMy
# ScAlEr AcAdEmY
# sCaLeR AcAdEmY
# sCaLeR aCaDeMy

# %% [markdown]
# Q8. Concatenation of Strings
#
# What is the output of the following python statement?
#
# print(“hello”+1+2+3)

# %%
# hello123 hello Error hello6

# %% [markdown]
# Q9. Changing String Values
#
# What will be the output of the following code snippet?
#
# a = 'hello'
# b = a
# a = 'yello'
#
# print(b)
# print(a)
# Options:
#
# A) hello
#   yello
#
# B) hello
#   hello
#
# C) yello
#   yello
#
# D) Error

# %%
# A B C D

# %% [markdown]
# Q1. String Methods
#
# Match the string operations in column A with their correct output from column B with respect to string s.
#
# s = "My PO Box number is 310"
#
# ![WhatsApp Image 2023-04-14 at 16.33.04.jpeg](data:image/jpeg;base64,...)
#
#
# In column A, option c is print(s.startswith('My P'))

# %%
# a-ii, b-ii, c-i, d-ii
# a-i, b-ii, c-ii, d-i
# a-ii, b-ii, c-ii, d-ii
# a-i, b-i, c-i, d-ii

# %% [markdown]
# Q2. 'Hello' Strings
#
# Which options will raise error if s = "hello"?

# %%
# print(s[0:9]) s[2] = ‘a’ print( s[9] ) print( s[: : -1] )

# %% [markdown]
# Q3. Brown Fox
#
# Select the correct output of the following code:
#
# str1 = "quick brown fox word!"
# print(str1[12:15], str1[:5], str1[-5:-1], str1[8:110], str1[-4:])

# %%
# fox quick word own fox word! ord!
# fox word quick own word! fox ord!
# fox quick word owquick own ord!
# foxquickword!ownord!

# %% [markdown]
# Q4. Correct String Operations
#
# Select the correct output of the following String operations:
#
# str1 = "Hello"
# print(str1*2)

# %%
# HHeelllloo
# Hello*2
# HelloHello
# TypeError: Unsupported operand type(s)
